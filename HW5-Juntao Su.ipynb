# %%
from pymagnitude import *
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
from pandas.plotting import table 
file_path = "GoogleNews-vectors-negative300.magnitude"
vectors = Magnitude(file_path)

# %% [markdown]
# ### 1. What is the dimensionality of these word embeddings? Provide an integer answer.

# %%
vectors.dim
# Out:
# 300

# %% [markdown]
# ### 2. What are the top-5 most similar words to 'picnic' (not including picnic itself)?

# %%
result=vectors.most_similar(vectors.query("picnic"), topn = 6)
print(result)
# Out:
# [('picnic', 0.9999998), ('picnics', 0.7400875), ('picnic_lunch', 0.721374), ('Picnic', 0.700534), ('potluck_picnic', 0.6683274), ('picnic_supper', 0.65189123)]

# %%
output=DataFrame(result[1:],columns=['word','similarity'])
output.set_index('word').plot.bar()
plt.xlabel("word",fontsize=15)
plt.ylabel("similarity",fontsize=15)
plt.title('Q2:  What are the top-5 most similar words to picnic',fontsize=15)
plt.ylim([0,1])
plt.show()

# %%
ax = plt.subplot(111, frame_on=False) # no visible frame
ax.xaxis.set_visible(False)  # hide the x axis
ax.yaxis.set_visible(False)  # hide the y axis

table(ax, DataFrame(result[1:],columns=['word','similarity']))  # where df is your data frame
plt.show()

# %% [markdown]
# ### 3. According to the word embeddings, which of these words is not like the others? ['tissue', 'papyrus', 'manila', 'newsprint', 'parchment', 'gazette']

# %%
vectors.doesnt_match(["tissue", "papyrus", "manila", "newsprint", "parchment", "gazette"])
# Out:
# 'tissue'

# %% [markdown]
# ### 4. Solve the following analogy: 'leg' is to 'jump' as 'X' is to 'throw'.

# %%
vectors.most_similar(positive = ["leg", "throw"], negative = ["jump"])
# Forearm has the highest similarity
# Out:
# [('forearm', 0.48294652),
#  ('shin', 0.47376165),
#  ('elbow', 0.4679689),
#  ('metacarpal_bone', 0.46781474),
#  ('metacarpal_bones', 0.46605822),
#  ('ankle', 0.46434426),
#  ('shoulder', 0.46183354),
#  ('thigh', 0.45393682),
#  ('knee', 0.4455707),
#  ('ulna_bone', 0.4423491)]
